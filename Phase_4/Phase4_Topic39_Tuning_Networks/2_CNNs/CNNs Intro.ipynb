# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# Convolutional Neural Networks
#
# </p>
# </div>
#
# Data Science Cohort Live NYC July 2022
# <p>Phase 4: Topic 41</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="Images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %%
from PIL import Image, ImageOps
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Convolution Neural Networks (CNNs)
# - An architecture designed for visual pattern recognition
# - Classification/regression on image data

# %% [markdown]
# Why a new architecture?

# %%
dogey = Image.open("Images/dog.jpg")
dogey_grayscale = ImageOps.grayscale(dogey)
display(dogey_grayscale)
# Out:
# <PIL.Image.Image image mode=L size=496x503>

# %%
dg_array = np.array(dogey_grayscale)
dg_array
# Out:
# array([[154, 150, 149, ..., 217, 216, 216],
#        [153, 149, 147, ..., 217, 216, 216],
#        [150, 146, 145, ..., 217, 216, 216],
#        ...,
#        [214, 214, 213, ..., 127, 128, 129],
#        [214, 213, 213, ..., 120, 122, 123],
#        [213, 213, 212, ..., 116, 118, 120]], dtype=uint8)

# %% [markdown]
# Pixel values: high local correlations across columns/rows.

# %% [markdown]
# The problem with standard neural network (aka multilayer perceptron network):
# - let's flatten the doge and inspect features.

# %%
flattened_input = np.ravel(dg_array)
len(flattened_input)
# Out:
# 249488

# %% [markdown]
# All those features go in to MLP:

# %% [markdown]
# <center><img src = "Images/mlp_image.jfif" width =600/></center>
# <center> Number of weights to first layer: huge

# %% [markdown]
# Treats features as independent:
# - Large number of features.
# - Dense connections: large number of weights to tune
# - Weights trying to learn pixel-level correlations

# %% [markdown]
# Not a good idea. Too specific.

# %% [markdown]
# Want to start model at a much higher level of feature abstraction

# %% [markdown]
# #### Building up the convolutional network

# %% [markdown]
# <center><img src = "Images/mlp-convolution-transform.webp" width = 500>

# %% [markdown]
# Cutting connections:
# - not all pixel-pixel interactions relevant.
# - only pass neighboring pixels into given node at next layer.
#
# **Keeps information local**

# %% [markdown]
# <img src = "Images/convolution-mlp-mapping.webp" >

# %% [markdown]
# Full computation corresponds to **convolution**
#
# $$ \begin{bmatrix}
# x_{11} & x_{12} & x_{13} \\
# x_{21} & x_{22} & x_{23} \\
# x_{31} & x_{32} & x_{33}
# \end{bmatrix} *
# \begin{bmatrix}
# w_1 & w_2 \\
# w_3 & w_4
# \end{bmatrix} = \\
# \begin{bmatrix}
# w_1x_{11} + w_2x_{12} + w_3x_{21} + w_4x_{22} & w_1x_{12} + w_2x_{13} + w_3x_{22} + w_4x_{23} \\
# w_1x_{21} + w_2x_{22} + w_3x_{31} + w_4x_{32} & w_1 x_{22} + w_2x_{23} + w_3x_{32} + w_4x_{33}
# \end{bmatrix}$$

# %% [markdown]
# <center><img src = "Images/convolution-mlp-mapping.webp" width = 400 ></center>

# %% [markdown]
# Single node: element-wise multiplication and add them up.
# - A dot product between shared weights and relevant local inputs.

# %% [markdown]
# Convolution in non-flattened output representation:
# - Sliding window with element-wise multiplication/sum
# - Creates new image (2D matrix).

# %% [markdown]
# <center><img src = "Images/convolution.gif" ></center>

# %% [markdown]
# <center><img src = "Images/convolution-mlp-mapping.webp" width = 400 ></center>

# %% [markdown]
# Why applying same weights for the different computations?

# %% [markdown]
# **Weight sharing:**
#
# Idea is that same set of weight patterns useful throughout image:
# - the same kinds of correlations keep showing up across different local regions.

# %% [markdown]
# <img src = "Images/convolution-mlp-mapping.webp" >

# %% [markdown]
# Weights acts as filter:
# - regions with no vertical edge are zero.
# - regions with vertical edge register value.
# - useful in many local areas of image
#
# **Same weight set applied to many local areas**

# %% [markdown]
# <img src = "Images/edge_detector_large.png" >

# %% [markdown]
# Other useful lower-level image features (benefiting from weight sharing):
#
# - Corner/special points
# - region/blob detection

# %% [markdown]
# <img src = "Images/corner_blobs.jpg" >

# %% [markdown]
# Much higher level features:
# - don't need to model pixel level structure

# %% [markdown]
# With colors we have three color dimensions (R/G/B):
# - Filter has three channels (R/G/B)
# - R channel applies a weight set to red intensity pixel values
# - G channel applies another weight set to green, ...

# %% [markdown]
# - Element-wise multiplication/addition channel-wise
# - Add result from all channels together.
#
# <img src = "Images/convwithcolor.png" >

# %% [markdown]
# - Can manually construct sets of filters and feature engineer.
# - But main idea of CNN is to *learn* these filters.
# - Given weight matrix feature engineers: CNN learning image feature extraction.

# %% [markdown]
# Typically, want to learn multiple filters at the same time:
# - Apply each filter/convolve on inputs seperately.
# - Creates stacked output (3D numpy array)

# %% [markdown]
# <img src = "Images/conv_manyfilters_expanded.jpg" width = 200/>

# %% [markdown]
# Multiple filters with colors:
# - Each filter has number of channels
# - Equaling depth of input layer.

# %% [markdown]
# Depth of output is equal to number of filters.

# %% [markdown]
# <img src = "Images/convcolormultifilters.png"  >

# %% [markdown]
# After each convolution operation:
# - apply nonlinear activation to output elementwise.

# %% [markdown]
# <img src = "Images/conv_activation.png" >

# %% [markdown]
# Putting it together: a schematic CNN on a gray-scale image.

# %% [markdown]
# <img src = "Images/conv_manyfilters.png" />

# %% [markdown]
# Haven't seen subsampling/aggregation/pooling yet.

# %% [markdown]
# Putting it together: a schematic CNN on a color image.

# %% [markdown]
# <img src = "Images/colorcnn.png" >

# %% [markdown]
# Haven't seen subsampling/aggregation/pooling yet.

# %% [markdown]
# #### Subsampling/aggregation: pooling layers
#
# - Pooling performs aggregation within window.
# - Stride pooling window across input.
# - Returns reduced representation.
#
#
# *Most common aggregation*: **max pooling**

# %% [markdown]
# <img src = "Images/maxpool.gif" >

# %% [markdown]
# **Intuition behind max pooling**
# - Reducing representation size.
# - Max: selecting on most distinctive feature.
# - Makes insensitive to translation/rotation of features.

# %% [markdown]
# <img src = "Images/maxpool.gif" >

# %% [markdown]
# <center><img src = "Images/translation_invariance_maxpool.jpg" ></center>

# %% [markdown]
# Repeated convolution/pooling:
# - Creates smaller feature maps laterally but more of them.
# - Encodes higher level features and condenses info.

# %% [markdown]
# <img src = "Images/conv_with_pooling_network.jpeg" >

# %% [markdown]
# Final steps involves flattening/connecting to dense fully-connected network:
# - take high level condensed features.
# - learn correct combinations of them.
# - put into sigmoid/softmax

# %% [markdown]
# <img src = "Images/conv_with_pooling_network.jpeg" >

# %% [markdown]
# Apply this to the MNIST digit recognition problem:

# %% [markdown]
# Some old imports:

# %%
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense # creates densely connected layer object
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array

# %% [markdown]
# The new layers

# %%
from tensorflow.keras.layers import Conv2D # convolution layer
from tensorflow.keras.layers import MaxPooling2D # max pooling layer

# %% [markdown]
# Load MNIST

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_labels = to_categorical(train_labels)

# %% [markdown]
# Conv2D takes tensors of shape:
# - (image_height, image_width, color_channels) for each image
# - MNIST has one color channel (grayscale).

# %%
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# %%
train_images.shape
train_labels.shape
# Out:
# (60000, 10)

# %% [markdown]
# Normalize data

# %%
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255, test_images / 255

# %% [markdown]
# Create the CNN sequential model.

# %%
model = Sequential()
# define 3x3 filter window sizes. Create 32 filters.
model.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(28, 28, 1)))
# max pool in 2x2 window
model.add(MaxPooling2D(pool_size=(2, 2)))
# define 3x3 filter window sizes. Create 64 filters.
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))

# transition to dense fully-connected part of network
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# 2022-12-06 16:13:19.339636: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-06 16:13:19.339750: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Pro

# %% [markdown]
# Let display the architecture of our model so far.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compile and train the model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn = model.fit(train_images, train_labels, epochs= 20, validation_split = 0.2, batch_size=32, verbose = 2)
# Out:
# Epoch 1/20
# 2022-12-06 16:13:20.175139: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-06 16:13:20.391762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-06 16:13:36.518541: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1500/1500 - 19s - loss: 0.1734 - accuracy: 0.9462 - val_loss: 0.0610 - val_accuracy: 0.9807 - 19s/epoch - 12ms/step
# Epoch 2/20
# 1500/1500 - 15s - loss: 0.0514 - accuracy: 0.9843 - val_loss: 0.0485 - val_accuracy: 0.9861 - 15s/epoch - 10ms/step
# Epoch 3/20
# 1500/1500 - 16s - loss: 0.0369 - accuracy: 0.9880 - val_loss: 0.0438 - val_accuracy: 0.9867 - 16s/epoch - 10ms/step
# Epoch 4/20
# 1500/1500 - 16s - loss: 0.0278 - accuracy: 0.9909 - val_loss: 0.0458 - val_accuracy: 0.9860 - 16s/epoch - 10ms/step
# Epoch 5/20
# 1500/1500 - 16s - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.0416 - val_accuracy: 0.9896 - 16s/epoch - 10ms/step
# Epoch 6/20
# 1500/1500 - 15s - loss: 0.0176 - accuracy: 0.9938 - val_loss: 0.0509 - val_accuracy: 0.9875 - 15s/epoch - 10ms/step
# Epoch 7/20
# 1500/1500 - 15s - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.0521 - val_accuracy: 0.9868 - 15s/epoch - 10ms/step
# Epoch 8/20
# 1500/1500 - 15s - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.0376 - val_accuracy: 0.9914 - 15s/epoch - 10ms/step
# Epoch 9/20
# 1500/1500 - 15s - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.0448 - val_accuracy: 0.9900 - 15s/epoch - 10ms/step
# Epoch 10/20
# 1500/1500 - 15s - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0498 - val_accuracy: 0.9893 - 15s/epoch - 10ms/step
# Epoch 11/20
# 1500/1500 - 15s - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0476 - val_accuracy: 0.9886 - 15s/epoch - 10ms/step
# Epoch 12/20
# 1500/1500 - 15s - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0555 - val_accuracy: 0.9877 - 15s/epoch - 10ms/step
# Epoch 13/20
# 1500/1500 - 15s - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0548 - val_accuracy: 0.9893 - 15s/epoch - 10ms/step
# Epoch 14/20
# 1500/1500 - 15s - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0563 - val_accuracy: 0.9906 - 15s/epoch - 10ms/step
# Epoch 15/20
# 1500/1500 - 15s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0559 - val_accuracy: 0.9898 - 15s/epoch - 10ms/step
# Epoch 16/20
# 1500/1500 - 15s - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0687 - val_accuracy: 0.9872 - 15s/epoch - 10ms/step
# Epoch 17/20
# 1500/1500 - 15s - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0581 - val_accuracy: 0.9897 - 15s/epoch - 10ms/step
# Epoch 18/20
# 1500/1500 - 15s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0525 - val_accuracy: 0.9899 - 15s/epoch - 10ms/step
# Epoch 19/20
# 1500/1500 - 15s - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0554 - val_accuracy: 0.9908 - 15s/epoch - 10ms/step
# Epoch 20/20
# 1500/1500 - 15s - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0599 - val_accuracy: 0.9900 - 15s/epoch - 10ms/step

# %% [markdown]
# #### Evaluate the model

# %%
_, test_acc = model.evaluate(test_images, to_categorical(test_labels), verbose =2)
# Out:
# 2022-12-06 16:18:30.969550: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 - 2s - loss: 0.0562 - accuracy: 0.9905 - 2s/epoch - 8ms/step

# %%
print(test_acc)
# Out:
# 0.9905000329017639

# %%
train_cnn_history = pd.DataFrame(history_cnn.history)
train_cnn_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_cnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_cnn_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Overfitting has occurred: further training is not improving the validation scores in anyway.

# %% [markdown]
# Can we improve this by regularization techniques?
# - typically we add dropout and L2 regularization after the convolutional layers

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

# a new layer that rescales/normalizes the activations after each layer.
# has a weak regularization effect. also allows 

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation

# %%
model2 = Sequential()
# define 3x3 filter window sizes. Create 32 filters.
model2.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(28, 28, 1), kernel_regularizer = l2(5e-4) ))

model2.add(BatchNormalization())
# max pool in 2x2 window
model2.add(MaxPooling2D(pool_size=(2, 2)))
# define 3x3 filter window sizes. Create 64 filters.
model2.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))

model2.add(BatchNormalization())
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4)))

model2.add(BatchNormalization())

# transition to dense fully-connected part of network
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.2))

model2.add(BatchNormalization())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.25))

model2.add(BatchNormalization())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_reg = model2.fit(train_images, train_labels, epochs= 50, validation_split = 0.2, batch_size=64)
# Out:
# Epoch 1/50
# 2022-12-06 16:18:34.120131: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 748/750 [============================>.] - ETA: 0s - loss: 0.2779 - accuracy: 0.9342
# 2022-12-06 16:18:51.952275: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 750/750 [==============================] - 20s 22ms/step - loss: 0.2775 - accuracy: 0.9343 - val_loss: 0.1263 - val_accuracy: 0.9796
# Epoch 2/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.1184 - accuracy: 0.9809 - val_loss: 0.1013 - val_accuracy: 0.9854
# Epoch 3/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.1035 - accuracy: 0.9833 - val_loss: 0.1059 - val_accuracy: 0.9814
# Epoch 4/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0861 - accuracy: 0.9875 - val_loss: 0.0842 - val_accuracy: 0.9875
# Epoch 5/50
# 750/750 [==============================] - 17s 23ms/step - loss: 0.0812 - accuracy: 0.9873 - val_loss: 0.0782 - val_accuracy: 0.9887
# Epoch 6/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0734 - accuracy: 0.9892 - val_loss: 0.0767 - val_accuracy: 0.9883
# Epoch 7/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0725 - accuracy: 0.9892 - val_loss: 0.0765 - val_accuracy: 0.9893
# Epoch 8/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0681 - accuracy: 0.9897 - val_loss: 0.0749 - val_accuracy: 0.9881
# Epoch 9/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0678 - accuracy: 0.9902 - val_loss: 0.0746 - val_accuracy: 0.9887
# Epoch 10/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0601 - accuracy: 0.9922 - val_loss: 0.0751 - val_accuracy: 0.9884
# Epoch 11/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0619 - accuracy: 0.9911 - val_loss: 0.0867 - val_accuracy: 0.9853
# Epoch 12/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0627 - accuracy: 0.9906 - val_loss: 0.0719 - val_accuracy: 0.9895
# Epoch 13/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0585 - accuracy: 0.9917 - val_loss: 0.0899 - val_accuracy: 0.9843
# Epoch 14/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0557 - accuracy: 0.9925 - val_loss: 0.0850 - val_accuracy: 0.9858
# Epoch 15/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0553 - accuracy: 0.9926 - val_loss: 0.0727 - val_accuracy: 0.9892
# Epoch 16/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0540 - accuracy: 0.9925 - val_loss: 0.0819 - val_accuracy: 0.9852
# Epoch 17/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0518 - accuracy: 0.9932 - val_loss: 0.0762 - val_accuracy: 0.9885
# Epoch 18/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0499 - accuracy: 0.9930 - val_loss: 0.0665 - val_accuracy: 0.9906
# Epoch 19/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0481 - accuracy: 0.9939 - val_loss: 0.0656 - val_accuracy: 0.9895
# Epoch 20/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0500 - accuracy: 0.9930 - val_loss: 0.0620 - val_accuracy: 0.9908
# Epoch 21/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0498 - accuracy: 0.9937 - val_loss: 0.0604 - val_accuracy: 0.9908
# Epoch 22/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0434 - accuracy: 0.9945 - val_loss: 0.0672 - val_accuracy: 0.9888
# Epoch 23/50
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0481 - accuracy: 0.9935 - val_loss: 0.0638 - val_accuracy: 0.9905
# Epoch 24/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0451 - accuracy: 0.9945 - val_loss: 0.0581 - val_accuracy: 0.9909
# Epoch 25/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0431 - accuracy: 0.9947 - val_loss: 0.0606 - val_accuracy: 0.9907
# Epoch 26/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0422 - accuracy: 0.9945 - val_loss: 0.0800 - val_accuracy: 0.9846
# Epoch 27/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0452 - accuracy: 0.9939 - val_loss: 0.0632 - val_accuracy: 0.9915
# Epoch 28/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0413 - accuracy: 0.9949 - val_loss: 0.0721 - val_accuracy: 0.9862
# Epoch 29/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0413 - accuracy: 0.9948 - val_loss: 0.0584 - val_accuracy: 0.9914
# Epoch 30/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0406 - accuracy: 0.9950 - val_loss: 0.0566 - val_accuracy: 0.9911
# Epoch 31/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0407 - accuracy: 0.9949 - val_loss: 0.0564 - val_accuracy: 0.9916
# Epoch 32/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0379 - accuracy: 0.9955 - val_loss: 0.0685 - val_accuracy: 0.9891
# Epoch 33/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0384 - accuracy: 0.9953 - val_loss: 0.0611 - val_accuracy: 0.9908
# Epoch 34/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0401 - accuracy: 0.9948 - val_loss: 0.0591 - val_accuracy: 0.9911
# Epoch 35/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0381 - accuracy: 0.9954 - val_loss: 0.0592 - val_accuracy: 0.9910
# Epoch 36/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0368 - accuracy: 0.9960 - val_loss: 0.0625 - val_accuracy: 0.9897
# Epoch 37/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0342 - accuracy: 0.9960 - val_loss: 0.0651 - val_accuracy: 0.9896
# Epoch 38/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0373 - accuracy: 0.9952 - val_loss: 0.0717 - val_accuracy: 0.9877
# Epoch 39/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0378 - accuracy: 0.9953 - val_loss: 0.0585 - val_accuracy: 0.9912
# Epoch 40/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0373 - accuracy: 0.9956 - val_loss: 0.0523 - val_accuracy: 0.9927
# Epoch 41/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0343 - accuracy: 0.9956 - val_loss: 0.0620 - val_accuracy: 0.9889
# Epoch 42/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0327 - accuracy: 0.9965 - val_loss: 0.0494 - val_accuracy: 0.9920
# Epoch 43/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0342 - accuracy: 0.9959 - val_loss: 0.0579 - val_accuracy: 0.9912
# Epoch 44/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0353 - accuracy: 0.9956 - val_loss: 0.0574 - val_accuracy: 0.9915
# Epoch 45/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0340 - accuracy: 0.9962 - val_loss: 0.0530 - val_accuracy: 0.9922
# Epoch 46/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0334 - accuracy: 0.9960 - val_loss: 0.0530 - val_accuracy: 0.9916
# Epoch 47/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0330 - accuracy: 0.9959 - val_loss: 0.0543 - val_accuracy: 0.9926
# Epoch 48/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0343 - accuracy: 0.9958 - val_loss: 0.0597 - val_accuracy: 0.9909
# Epoch 49/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0309 - accuracy: 0.9965 - val_loss: 0.0626 - val_accuracy: 0.9896
# Epoch 50/50
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0305 - accuracy: 0.9964 - val_loss: 0.0563 - val_accuracy: 0.9917

# %%
_, test2_acc = model2.evaluate(test_images, to_categorical(test_labels))
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0530 - accuracy: 0.9927

# %%
train_regcnn_history = pd.DataFrame(history_reg.history)
train_regcnn_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_regcnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
train_regcnn_history = pd.DataFrame(history_reg.history)
train_regcnn_history.index.name = 'epochs'

col_list = ['accuracy', 'val_accuracy']
train_regcnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Changing architecture: simple CNN
# - really high test accuracy.
# - slight overfitting but still good.

# %% [markdown]
# To do much better: many orders of magnitude higher complexity to networks
# - very deep networks required
# - need regularization (L2/dropout)
# - other techniques (batchnorm, skip connections, 1D convolutions etc.)

# %% [markdown]
# Many highly successful pre-trained models exist that can be leveraged:
# - VGG16
# - Resnets
# - Inception Networks

# %% [markdown]
# **Or also just need more data.**
